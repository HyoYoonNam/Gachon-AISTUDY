# %% [markdown]
# **Dataset:** [Raisin](https://archive.ics.uci.edu/dataset/850/raisin)
#
# **Environment**
# * Windows-native: Version `Windows10-x64-Professional-22H2`
#
# **Framework**
# * TensorFlow: Version `2.10.1`
#
# **Dependencies**
# * Python: Version `3.9.19`
# * Pandas: Version `2.2.2`
# * Numpy: Version `1.26.4`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import tensorflow as tf
from tensorflow import keras

# %%
# Load the dataset
df = pd.read_excel('../Datasets/Raisin_Dataset/Raisin_Dataset.xlsx')
df

# 'Class'의 dtype이 object인 것이 확인됨
# Out:
#       Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0    87524       442.246011       253.291155      0.819738       90546
# 1    75166       406.690687       243.032436      0.801805       78789
# 2    90856       442.267048       266.328318      0.798354       93717
# 3    45928       286.540559       208.760042      0.684989       47336
# 4    79408       352.190770       290.827533      0.564011       81463
# ..     ...              ...              ...           ...         ...
# 895  83248       430.077308       247.838695      0.817263       85839
# 896  87350       440.735698       259.293149      0.808629       90899
# 897  99657       431.706981       298.837323      0.721684      106264
# 898  93523       476.344094       254.176054      0.845739       97653
# 899  85609       512.081774       215.271976      0.907345       89197
#
#        Extent  Perimeter    Class
# 0    0.758651   1184.040  Kecimen
# 1    0.684130   1121.786  Kecimen
# 2    0.637613   1208.575  Kecimen
# 3    0.699599    844.162  Kecimen
# 4    0.792772   1073.251  Kecimen
# ..        ...        ...      ...
# 895  0.668793   1129.072    Besni
# 896  0.636476   1214.252    Besni
# 897  0.741099   1292.828    Besni
# 898  0.658798   1258.548    Besni
# 899  0.632020   1272.862    Besni
#
# [900 rows x 8 columns]

# %%
# 'Class'의 종류를 확인
pd.unique(df['Class']) # Output: Kecimen, Besni
# Out:
# array(['Kecimen', 'Besni'], dtype=object)

# %%
# 'Class'를 integer에 matching시켜 dtype을 변경
df['Class'] = df['Class'].map({'Kecimen': 0, 'Besni': 1})
df
# Out:
#       Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0    87524       442.246011       253.291155      0.819738       90546
# 1    75166       406.690687       243.032436      0.801805       78789
# 2    90856       442.267048       266.328318      0.798354       93717
# 3    45928       286.540559       208.760042      0.684989       47336
# 4    79408       352.190770       290.827533      0.564011       81463
# ..     ...              ...              ...           ...         ...
# 895  83248       430.077308       247.838695      0.817263       85839
# 896  87350       440.735698       259.293149      0.808629       90899
# 897  99657       431.706981       298.837323      0.721684      106264
# 898  93523       476.344094       254.176054      0.845739       97653
# 899  85609       512.081774       215.271976      0.907345       89197
#
#        Extent  Perimeter  Class
# 0    0.758651   1184.040      0
# 1    0.684130   1121.786      0
# 2    0.637613   1208.575      0
# 3    0.699599    844.162      0
# 4    0.792772   1073.251      0
# ..        ...        ...    ...
# 895  0.668793   1129.072      1
# 896  0.636476   1214.252      1
# 897  0.741099   1292.828      1
# 898  0.658798   1258.548      1
# 899  0.632020   1272.862      1
#
# [900 rows x 8 columns]

# %%
# Check the missing value
# 먼저, df 전체에서 missing value가 있는지 확인
if df.isnull().sum().sum() == 0:
    print("no missing values.")
# missing value가 존재한다면, 각 column에서의 수를 리턴
else:
    print(df.isnull().sum())
# Out:
# no missing values.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             900 non-null    int64
#  1   MajorAxisLength  900 non-null    float64
#  2   MinorAxisLength  900 non-null    float64
#  3   Eccentricity     900 non-null    float64
#  4   ConvexArea       900 non-null    int64
#  5   Extent           900 non-null    float64
#  6   Perimeter        900 non-null    float64
#  7   Class            900 non-null    int64
# dtypes: float64(5), int64(3)
# memory usage: 56.4 KB

# %%
df.describe()
# Out:
#                 Area  MajorAxisLength  MinorAxisLength  Eccentricity  \
# count     900.000000       900.000000       900.000000    900.000000
# mean    87804.127778       430.929950       254.488133      0.781542
# std     39002.111390       116.035121        49.988902      0.090318
# min     25387.000000       225.629541       143.710872      0.348730
# 25%     59348.000000       345.442898       219.111126      0.741766
# 50%     78902.000000       407.803951       247.848409      0.798846
# 75%    105028.250000       494.187014       279.888575      0.842571
# max    235047.000000       997.291941       492.275279      0.962124
#
#           ConvexArea      Extent    Perimeter       Class
# count     900.000000  900.000000   900.000000  900.000000
# mean    91186.090000    0.699508  1165.906636    0.500000
# std     40769.290132    0.053468   273.764315    0.500278
# min     26139.000000    0.379856   619.074000    0.000000
# 25%     61513.250000    0.670869   966.410750    0.000000
# 50%     81651.000000    0.707367  1119.509000    0.500000
# 75%    108375.750000    0.734991  1308.389750    1.000000
# max    278217.000000    0.835455  2697.753000    1.000000

# %%
# Check the columns
df.columns
# Out:
# Index(['Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity',
#        'ConvexArea', 'Extent', 'Perimeter', 'Class'],
#       dtype='object')

# %%
# Check the label count - by graph
sns.countplot(data=df, x='Class')
plt.xlabel('Kecimen(0) or Besni(1)')
plt.ylabel('Count')
plt.title('Class')
plt.show()

# %%
# Check the label count - by numeri table
df['Class'].value_counts()
# Out:
# Class
# 0    450
# 1    450
# Name: count, dtype: int64

# %%
# Check the correlations by `sns.heatmap`
# If corr >= 0.3, positive-correlated and if corr >= 0.7, high correlated
# If corr <= -0.3, negative-correlated and if corr <= -0.7, high correlated
df_corr = df.corr()

plt.figure(figsize=(10, 10))
sns.set(font_scale=0.8)
sns.heatmap(data=df_corr, annot=True)
plt.show()

# positive-correlated with 'Class'
# Except for 'Extent', all features have a positive correlation with 'Class'.

# %%
# check the correlations by `sns.pairplot`
sns.pairplot(data=df,
             vars=df.columns,
             hue='Class')
plt.show()

# %%
# cf. 해당 색상들이 순서대로 부여됨 즉, blue=>label 0이고 orange=>label 1
sns.color_palette()
# Out:
# [(0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#  (0.8666666666666667, 0.5176470588235295, 0.3215686274509804),
#  (0.3333333333333333, 0.6588235294117647, 0.40784313725490196),
#  (0.7686274509803922, 0.3058823529411765, 0.3215686274509804),
#  (0.5058823529411764, 0.4470588235294118, 0.7019607843137254),
#  (0.5764705882352941, 0.47058823529411764, 0.3764705882352941),
#  (0.8549019607843137, 0.5450980392156862, 0.7647058823529411),
#  (0.5490196078431373, 0.5490196078431373, 0.5490196078431373),
#  (0.8, 0.7254901960784313, 0.4549019607843137),
#  (0.39215686274509803, 0.7098039215686275, 0.803921568627451)]

# %%
# split dataset into X(features) and y(label)
X = df.drop('Class', axis=1).to_numpy()
y = df['Class'].to_numpy()

print(f'X: Shape {X.shape}, y: Shape {y.shape}')
print(X[:3])
print(y[:3])
# Out:
# X: Shape (900, 7), y: Shape (900,)
# [[8.75240000e+04 4.42246011e+02 2.53291155e+02 8.19738392e-01
#   9.05460000e+04 7.58650579e-01 1.18404000e+03]
#  [7.51660000e+04 4.06690687e+02 2.43032436e+02 8.01805234e-01
#   7.87890000e+04 6.84129570e-01 1.12178600e+03]
#  [9.08560000e+04 4.42267048e+02 2.66328318e+02 7.98353619e-01
#   9.37170000e+04 6.37612812e-01 1.20857500e+03]]
# [0 0 0]

# %%
# Standardization
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)
print(X[:3])
# Out:
# [[-0.00718637  0.09757695 -0.02395819  0.42314164 -0.01570903  1.10674264
#    0.06627397]
#  [-0.32421719 -0.20901207 -0.22929222  0.22447639 -0.3042482  -0.28777679
#   -0.16125245]
#  [ 0.07829241  0.09775835  0.23698797  0.18623907  0.06211335 -1.15824974
#    0.15594468]]

# %% [markdown]
# **cf. [sklearn.preprocessing StandardScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html)**

# %%
# One-hot encoding
def one_hot_encode(labels, num_classes):
    # labels: 클래스 인덱스가 포함된 배열
    # num_classes: 총 클래스의 수
    
    # label을 index로 사용,
    # label에 해당하는 index만 1.이고 나머지는 0.인,
    # 길이가 num_classes인 ndarray 리턴
    one_hot = np.eye(num_classes)[labels]
    
    return one_hot

num_classes = len(np.unique(y)) # np.unique(y) = [0, 1]

y_onehot = one_hot_encode(y, num_classes)
print(y_onehot[:3])
# Out:
# [[1. 0.]
#  [1. 0.]
#  [1. 0.]]

# %% [markdown]
# **cf. [numpy.eye](https://numpy.org/devdocs/reference/generated/numpy.eye.html)**
#
# 기본적으로 `np.eye(N)`는 N by N의 2-dim 단위 행렬(대각선 요소만 1인 행렬)을 리턴함.
# ```python
# np.eye(3)
# > array([[1., 0., 0.],
#          [0., 1., 0.],
#          [0., 0., 1.]])
# ```
#
# `np.eye(N)[idx]`와 같이 사용하면 length가 N이고, idx의 element만 1이고, 나머지는 0인 1-dim array를 리턴함.
# ```python
# np.eye(3)[1]
# > array([0., 1., 0.])
# ```

# %%
# Split the X and y_onehot into train, test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y_onehot,
                                                    test_size=0.2,
                                                    stratify=y_onehot,
                                                    random_state=42)

print(f'X_train: Shape {X_train.shape}, y_train: Shape {y_train.shape}')
print(f'X_test: Shape {X_test.shape}, y_test: Shape {y_test.shape}')
# Out:
# X_train: Shape (720, 7), y_train: Shape (720, 2)
# X_test: Shape (180, 7), y_test: Shape (180, 2)

# %%
X_train_reshaped = X_train.reshape((-1, 7, 1))
X_test_reshaped = X_test.reshape((-1, 7, 1))

# %%
X_train_reshaped.shape
# Out:
# (720, 7, 1)

# %%
model = keras.Sequential()
model.add(keras.layers.Conv1D(filters=32,
                              kernel_size=3,
                              activation='relu',
                              padding='same',
                              # (steps, channels) 
                              input_shape=(7, 1)))
model.add(keras.layers.Conv1D(filters=64,
                               kernel_size=3,
                               activation='relu',
                               padding='same'))
# 기본적으로 Conv1D(2D도 마찬가지)는 channel-dim을 필요로 함.
# 따라서 위 cell에서 features가 7개인 기본 shape에 channel을 추가하여,
# (7,)에서 (7, 1)로 reshape했음.
# Dense로 보내기 위해서는 다시 Flatten이 필요함
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(units=64,
                             activation='relu'))
model.add(keras.layers.Dense(units=2,
                             activation='sigmoid'))


model.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_26 (Conv1D)          (None, 7, 32)             128
#
#  conv1d_27 (Conv1D)          (None, 7, 64)             6208
#
#  flatten_17 (Flatten)        (None, 448)               0
#
#  dense_42 (Dense)            (None, 64)                28736
#
#  dense_43 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 35,202
# Trainable params: 35,202
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(X_train_reshaped, y_train,
                    validation_split=0.1,
                    batch_size=None,
                    epochs=50,
                    verbose=2)
# Out:
# Epoch 1/50
# 21/21 - 1s - loss: 0.4395 - accuracy: 0.8302 - val_loss: 0.2777 - val_accuracy: 0.8889 - 766ms/epoch - 36ms/step
# Epoch 2/50
# 21/21 - 0s - loss: 0.3482 - accuracy: 0.8596 - val_loss: 0.2505 - val_accuracy: 0.8889 - 161ms/epoch - 8ms/step
# Epoch 3/50
# 21/21 - 0s - loss: 0.3415 - accuracy: 0.8611 - val_loss: 0.2824 - val_accuracy: 0.8750 - 163ms/epoch - 8ms/step
# Epoch 4/50
# 21/21 - 0s - loss: 0.3443 - accuracy: 0.8657 - val_loss: 0.2662 - val_accuracy: 0.8889 - 147ms/epoch - 7ms/step
# Epoch 5/50
# 21/21 - 0s - loss: 0.3431 - accuracy: 0.8627 - val_loss: 0.2785 - val_accuracy: 0.9028 - 150ms/epoch - 7ms/step
# Epoch 6/50
# 21/21 - 0s - loss: 0.3389 - accuracy: 0.8657 - val_loss: 0.2721 - val_accuracy: 0.8750 - 151ms/epoch - 7ms/step
# Epoch 7/50
# 21/21 - 0s - loss: 0.3372 - accuracy: 0.8642 - val_loss: 0.2697 - val_accuracy: 0.8889 - 150ms/epoch - 7ms/step
# Epoch 8/50
# 21/21 - 0s - loss: 0.3341 - accuracy: 0.8627 - val_loss: 0.2637 - val_accuracy: 0.8889 - 143ms/epoch - 7ms/step
# Epoch 9/50
# 21/21 - 0s - loss: 0.3334 - accuracy: 0.8673 - val_loss: 0.2499 - val_accuracy: 0.8889 - 146ms/epoch - 7ms/step
# Epoch 10/50
# 21/21 - 0s - loss: 0.3308 - accuracy: 0.8596 - val_loss: 0.2598 - val_accuracy: 0.9028 - 148ms/epoch - 7ms/step
# Epoch 11/50
# 21/21 - 0s - loss: 0.3291 - accuracy: 0.8642 - val_loss: 0.2737 - val_accuracy: 0.9028 - 141ms/epoch - 7ms/step
# Epoch 12/50
# 21/21 - 0s - loss: 0.3247 - accuracy: 0.8596 - val_loss: 0.2565 - val_accuracy: 0.9028 - 153ms/epoch - 7ms/step
# Epoch 13/50
# 21/21 - 0s - loss: 0.3263 - accuracy: 0.8642 - val_loss: 0.2487 - val_accuracy: 0.9028 - 143ms/epoch - 7ms/step
# Epoch 14/50
# 21/21 - 0s - loss: 0.3281 - accuracy: 0.8611 - val_loss: 0.2742 - val_accuracy: 0.8889 - 142ms/epoch - 7ms/step
# Epoch 15/50
# 21/21 - 0s - loss: 0.3216 - accuracy: 0.8719 - val_loss: 0.2589 - val_accuracy: 0.9028 - 235ms/epoch - 11ms/step
# Epoch 16/50
# 21/21 - 0s - loss: 0.3203 - accuracy: 0.8673 - val_loss: 0.2536 - val_accuracy: 0.8750 - 129ms/epoch - 6ms/step
# Epoch 17/50
# 21/21 - 0s - loss: 0.3216 - accuracy: 0.8688 - val_loss: 0.2653 - val_accuracy: 0.9028 - 115ms/epoch - 5ms/step
# Epoch 18/50
# 21/21 - 0s - loss: 0.3154 - accuracy: 0.8719 - val_loss: 0.2636 - val_accuracy: 0.8889 - 119ms/epoch - 6ms/step
# Epoch 19/50
# 21/21 - 0s - loss: 0.3153 - accuracy: 0.8688 - val_loss: 0.2614 - val_accuracy: 0.8889 - 120ms/epoch - 6ms/step
# Epoch 20/50
# 21/21 - 0s - loss: 0.3082 - accuracy: 0.8765 - val_loss: 0.2670 - val_accuracy: 0.8889 - 112ms/epoch - 5ms/step
# Epoch 21/50
# 21/21 - 0s - loss: 0.3129 - accuracy: 0.8704 - val_loss: 0.2711 - val_accuracy: 0.9028 - 175ms/epoch - 8ms/step
# Epoch 22/50
# 21/21 - 0s - loss: 0.3045 - accuracy: 0.8704 - val_loss: 0.2714 - val_accuracy: 0.8889 - 120ms/epoch - 6ms/step
# Epoch 23/50
# 21/21 - 0s - loss: 0.3075 - accuracy: 0.8611 - val_loss: 0.2703 - val_accuracy: 0.9028 - 115ms/epoch - 5ms/step
# Epoch 24/50
# 21/21 - 0s - loss: 0.3026 - accuracy: 0.8719 - val_loss: 0.2587 - val_accuracy: 0.8889 - 159ms/epoch - 8ms/step
# Epoch 25/50
# 21/21 - 0s - loss: 0.3033 - accuracy: 0.8704 - val_loss: 0.2831 - val_accuracy: 0.8889 - 146ms/epoch - 7ms/step
# Epoch 26/50
# 21/21 - 0s - loss: 0.3005 - accuracy: 0.8719 - val_loss: 0.2519 - val_accuracy: 0.8750 - 107ms/epoch - 5ms/step
# Epoch 27/50
# 21/21 - 0s - loss: 0.3005 - accuracy: 0.8719 - val_loss: 0.2690 - val_accuracy: 0.8889 - 110ms/epoch - 5ms/step
# Epoch 28/50
# 21/21 - 0s - loss: 0.2970 - accuracy: 0.8673 - val_loss: 0.2642 - val_accuracy: 0.8889 - 110ms/epoch - 5ms/step
# Epoch 29/50
# 21/21 - 0s - loss: 0.3002 - accuracy: 0.8765 - val_loss: 0.2703 - val_accuracy: 0.9028 - 107ms/epoch - 5ms/step
# Epoch 30/50
# 21/21 - 0s - loss: 0.2963 - accuracy: 0.8688 - val_loss: 0.2894 - val_accuracy: 0.8889 - 106ms/epoch - 5ms/step
# Epoch 31/50
# 21/21 - 0s - loss: 0.2922 - accuracy: 0.8735 - val_loss: 0.2866 - val_accuracy: 0.9028 - 115ms/epoch - 5ms/step
# Epoch 32/50
# 21/21 - 0s - loss: 0.2930 - accuracy: 0.8704 - val_loss: 0.2671 - val_accuracy: 0.8750 - 119ms/epoch - 6ms/step
# Epoch 33/50
# 21/21 - 0s - loss: 0.2948 - accuracy: 0.8688 - val_loss: 0.2734 - val_accuracy: 0.9167 - 142ms/epoch - 7ms/step
# Epoch 34/50
# 21/21 - 0s - loss: 0.2921 - accuracy: 0.8735 - val_loss: 0.2721 - val_accuracy: 0.9028 - 114ms/epoch - 5ms/step
# Epoch 35/50
# 21/21 - 0s - loss: 0.2857 - accuracy: 0.8781 - val_loss: 0.2910 - val_accuracy: 0.8750 - 108ms/epoch - 5ms/step
# Epoch 36/50
# 21/21 - 0s - loss: 0.2857 - accuracy: 0.8735 - val_loss: 0.2825 - val_accuracy: 0.8750 - 108ms/epoch - 5ms/step
# Epoch 37/50
# 21/21 - 0s - loss: 0.2912 - accuracy: 0.8765 - val_loss: 0.2866 - val_accuracy: 0.8889 - 110ms/epoch - 5ms/step
# Epoch 38/50
# 21/21 - 0s - loss: 0.2861 - accuracy: 0.8781 - val_loss: 0.2832 - val_accuracy: 0.8889 - 120ms/epoch - 6ms/step
# Epoch 39/50
# 21/21 - 0s - loss: 0.2825 - accuracy: 0.8719 - val_loss: 0.3103 - val_accuracy: 0.8750 - 122ms/epoch - 6ms/step
# Epoch 40/50
# 21/21 - 0s - loss: 0.2862 - accuracy: 0.8750 - val_loss: 0.2613 - val_accuracy: 0.8750 - 124ms/epoch - 6ms/step
# Epoch 41/50
# 21/21 - 0s - loss: 0.2810 - accuracy: 0.8704 - val_loss: 0.2826 - val_accuracy: 0.9028 - 163ms/epoch - 8ms/step
# Epoch 42/50
# 21/21 - 0s - loss: 0.2835 - accuracy: 0.8719 - val_loss: 0.2847 - val_accuracy: 0.8889 - 121ms/epoch - 6ms/step
# Epoch 43/50
# 21/21 - 0s - loss: 0.2780 - accuracy: 0.8843 - val_loss: 0.2758 - val_accuracy: 0.9028 - 124ms/epoch - 6ms/step
# Epoch 44/50
# 21/21 - 0s - loss: 0.2814 - accuracy: 0.8827 - val_loss: 0.2773 - val_accuracy: 0.8889 - 136ms/epoch - 6ms/step
# Epoch 45/50
# 21/21 - 0s - loss: 0.2787 - accuracy: 0.8765 - val_loss: 0.2859 - val_accuracy: 0.8889 - 131ms/epoch - 6ms/step
# Epoch 46/50
# 21/21 - 0s - loss: 0.2763 - accuracy: 0.8765 - val_loss: 0.2732 - val_accuracy: 0.9028 - 115ms/epoch - 5ms/step
# Epoch 47/50
# 21/21 - 0s - loss: 0.2746 - accuracy: 0.8657 - val_loss: 0.3107 - val_accuracy: 0.8889 - 154ms/epoch - 7ms/step
# Epoch 48/50
# 21/21 - 0s - loss: 0.2717 - accuracy: 0.8827 - val_loss: 0.2972 - val_accuracy: 0.8750 - 139ms/epoch - 7ms/step
# Epoch 49/50
# 21/21 - 0s - loss: 0.2791 - accuracy: 0.8735 - val_loss: 0.2989 - val_accuracy: 0.8889 - 123ms/epoch - 6ms/step
# Epoch 50/50
# 21/21 - 0s - loss: 0.2737 - accuracy: 0.8873 - val_loss: 0.2962 - val_accuracy: 0.8750 - 126ms/epoch - 6ms/step

# %%
# Epoch에 따른 loss
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Epoch에 따른 accuracy
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Accuracy of the predicted values
from sklearn.metrics import classification_report, confusion_matrix

y_pred = model.predict(X_test_reshaped)
y_test_class = np.argmax(y_test, axis=1)
y_pred_class = np.argmax(y_pred, axis=1)

print(classification_report(y_test_class, y_pred_class))
print(confusion_matrix(y_test_class, y_pred_class))
# Out:
# 6/6 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.85      0.92      0.88        90
#            1       0.91      0.83      0.87        90
#
#     accuracy                           0.88       180
#    macro avg       0.88      0.88      0.88       180
# weighted avg       0.88      0.88      0.88       180
#
# [[83  7]
#  [15 75]]
